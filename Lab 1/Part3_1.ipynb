# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

img1 = cv2.imread('/content/gdrive/MyDrive/Image.jpeg')
cv2_imshow(img1)

print(img1.shape)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7FB86982C690>
# (400, 600, 3)

# %% [markdown]
# **1) Write a python program to read an image and save the image as a matrix to a .csv file using pandas**

# %%
# import required libraries
import matplotlib.image as img
import pandas as pd

# read an image
imageMat = img.imread('/content/gdrive/MyDrive/Image.jpeg')
print("Image shape:",imageMat.shape)

# if image is colored (RGB)
if(imageMat.shape[2] == 3):

# reshape it from 3D matrice to 2D matrice
  imageMat_reshape = imageMat.reshape(imageMat.shape[0],-1)
  print("Reshaping to 2D array:",imageMat_reshape.shape)

# if image is grayscale
else:
# remain as it is
 imageMat_reshape = imageMat
	
# converting it to dataframe.
mat_df = pd.DataFrame(imageMat_reshape)

# exporting dataframe to CSV file.
mat_df.to_csv('zainfile.csv',header = None,index = None)

# retrieving dataframe from CSV file
Zain_File = pd.read_csv('zainfile.csv',sep = ',',header = None)

# getting matrice values.
Zain_2D_mat = Zain_File.values
# Out:
# Image shape: (400, 600, 3)
# Reshaping to 2D array: (400, 1800)

# %%
Zain_File #CSV_File
# Out:
#      0     1     2     3     4     5     ...  1794  1795  1796  1797  1798  1799
# 0     239   225   178   249   235   190  ...   249   239   204   244   240   193
# 1     242   228   181   250   236   189  ...   254   244   208   250   246   201
# 2     242   228   179   248   234   187  ...   254   242   204   250   245   203
# 3     238   225   173   244   230   181  ...   255   241   204   250   242   203
# 4     233   220   167   239   226   174  ...   255   239   203   253   241   201
# ..    ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 395     9     5     2     8     4     1  ...   106   112    50    41    44     0
# 396     8     5     0     8     5     0  ...    91    92    26    44    39     0
# 397     9     6     1     8     5     0  ...    92    88    15    60    50     0
# 398     9     6     1     9     6     1  ...   113   104    25    81    66     0
# 399    10     7     2     9     6     1  ...   109    99    14    95    79     2
#
# [400 rows x 1800 columns]

# %%
Zain_2D_mat
# Out:
# array([[239, 225, 178, ..., 244, 240, 193],
#        [242, 228, 181, ..., 250, 246, 201],
#        [242, 228, 179, ..., 250, 245, 203],
#        ...,
#        [  9,   6,   1, ...,  60,  50,   0],
#        [  9,   6,   1, ...,  81,  66,   0],
#        [ 10,   7,   2, ...,  95,  79,   2]])
